# %% [markdown]
# ## Q1: Your next research project.
#
# Pick the directory of your current research project (your next paper!) and put it under version control.

# %%
from IPython.display import Image

# %% [markdown]
# My project folder is called "optical_depth_git" and now I put it under version control using git.
#
# I paste some screenshots from the terminal to show the commands I used for the procedure:

# %% [markdown]
# First I use "git init" to create a new .git folder to keep track of my work:

# %%
Image(filename='1.png')

# %% [markdown]
# Then I use "git add ." to track all the files inside my folder:

# %%
Image(filename='2.png')

# %% [markdown]
# Now I use "git commit -m" to commit all the files in my folder:

# %%
Image(filename='3.png')

# %% [markdown]
# Finally, I check the status with "git status" to see if everything has been updated:

# %%
Image(filename='4.png')

# %% [markdown]
# Now I make some changes in some of the files without updating them:

# %%
Image(filename='5.png')

# %% [markdown]
# Then I use add and check the status:

# %%
Image(filename='6.png')

# %% [markdown]
# Finally, I commit the changes:

# %%
Image(filename='7.png')

# %% [markdown]
# In the end, I check the status again to see if everything is ok:

# %%
Image(filename='8.png')

# %% [markdown]
# ## Q4: You're wrong
#
# Find a bug/typo in the material of this course, fix it, and send me a pull request.

# %% [markdown]
# I put here the commands I used in the terminal after I forked your repository and cloned it to my computer (I also created a new branch to work on rather than using the main) to correct some typos in lectures 3 and 8:

# %%
Image(filename='1a.png')

# %% [markdown]
# Then I sent you a pull request :)
